# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshay94/Deta-analyst-pw-skills-/blob/main/Python_Functions_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Python Programming Assignment **3**
#
# ---

# %% [markdown]
# # Theory Questions - python

# %% [markdown]
# ![WhatsApp Image 2024-11-25 at 3.55.27 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-11-25 at 3.55.28 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-11-25 at 3.55.28 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-11-25 at 3.55.29 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Practical Questions

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def sum_even_numbers(numbers):
    return sum(num for num in numbers if num % 2 == 0)

# Example usage
print(sum_even_numbers([1, 2, 3, 4, 5]))  # Output: 6

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
    return s[::-1]

# Example usage
print(reverse_string("hello"))  # Output: "olleh"

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_numbers(numbers):
    return [num ** 2 for num in numbers]

# Example usage
print(square_numbers([1, 2, 3]))  # Output: [1, 4, 9]

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

# Get all primes from 1 to 200
primes = [num for num in range(1, 201) if is_prime(num)]
print(primes)

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# %%
class Fibonacci:
    def __init__(self, terms):
        self.terms = terms
        self.a, self.b = 0, 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.terms <= 0:
            raise StopIteration
        self.a, self.b = self.b, self.a + self.b
        self.terms -= 1
        return self.a

# Example usage
fib = Fibonacci(5)
print(list(fib))  # Output: [1, 1, 2, 3, 5]

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

# Example usage
print(list(powers_of_two(5)))  # Output: [1, 2, 4, 8, 16, 32]

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()

# Example usage
# for line in read_file('example.txt'):
#     print(line)

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
tuples = [(1, 3), (2, 1), (4, 2)]
sorted_tuples = sorted(tuples, key=lambda x: x[1])
print(sorted_tuples)  # Output: [(2, 1), (4, 2), (1, 3)]

# %% [markdown]
# 9. Write a Python program that uses map() to convert a list of temperatures from Celsius to Fahrenheit.

# %%
temps_celsius = [0, 20, 40]
temps_fahrenheit = list(map(lambda c: (c * 9/5) + 32, temps_celsius))
print(temps_fahrenheit)  # Output: [32.0, 68.0, 104.0]

# %% [markdown]
# 10. Create a Python program that uses filter() to remove all the vowels from a given string.

# %%
def remove_vowels(s):
    vowels = 'aeiouAEIOU'
    return ''.join(filter(lambda x: x not in vowels, s))

# Example usage
print(remove_vowels("hello world"))  # Output: "hll wrld"

# %% [markdown]
# 11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
#
#   4 Order Number 34587 98762 77226 88112 Book Title and Author Quantity Learning Python, Mark Lutz Programming Python, Mark Lutz 5 Head First Python, Paul Barry 3 Einführung in Python3, Bernd Klein 3 Price per Item 40.95 56.80 32.95 24.99 Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by $10 if the value of the order is smaller than $100,00. Your Python program must use lambda and map.

# %%
# Data: Order details
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Use lambda and map to calculate the total cost for each order
# If the total is below $100, add a $10 charge
result = list(map(
    lambda order: (order[0], order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0)),
    orders
))

# Print the result
print(result)

# %% [markdown]
# Explanation:
#
# 1. Input Data: The orders list contains sublists with the following:
#
# *   Order number
# *   Book title and author
# * Quantity of books ordered
# * Price per item
#
# 2. Lambda Function:
#
# *   Calculates the total value of the order as quantity * price per item.
# *   Adds $10 to the total if it is below 100.
# 3. map() Function:
#
#
# *  Applies the lambda function to each sublist in the orders list
#
# 4. Result:
#
#
# *   Produces a list of tuples where each tuple contains
# *   Order number
# * Final total cost after applying the $10 condition

# %% [markdown]
# output

# %%
[(34587, 163.8), (98762, 284.0), (77226, 98.85), (88112, 84.97)]

# %% [markdown]
# How it Works:
#
# *Order 1:
# 4
# ×
# 40.95
# =
# 163.8
# 4×40.95=163.8 (No $10 added because it's above $100).
#
# *Order 2:
# 5
# ×
# 56.80
# =
# 284.0
# 5×56.80=284.0 (No $10 added because it's above $100).
#
# *Order 3:
# 3
# ×
# 32.95
# =
# 98.85
# 3×32.95=98.85 ($10 added, making it
# 98.85
# +
# 10
# =
# 108.85
# 98.85+10=108.85).
#
# *Order 4:
# 3
# ×
# 24.99
# =
# 74.97
# 3×24.99=74.97 ($10 added, making it
# 74.97
# +
# 10
# =
# 84.97
# 74.97+10=84.97).
